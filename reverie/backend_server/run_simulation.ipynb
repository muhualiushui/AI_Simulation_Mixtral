# %%
i=3
# for i in range(2,3):
# !echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/03_20/output$i"
# Out:
# ^C

# %%
import subprocess

repeat_count = 5

command = "4_15_test_5\n4_15_test_6"
for _ in range(repeat_count):
    command += "\nrun 1000"
command += "\nfin"

process = subprocess.Popen(['python3', 'reverie.py'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Send the command to the subprocess
process.stdin.write(command)
process.stdin.close()

# Read and print the output line by line in real time
while True:
    output_line = process.stdout.readline()
    if output_line == '' and process.poll() is not None:
        break
    if output_line:
        print(output_line.strip())

# Check for any errors
stderr = process.stderr.read()
if stderr:
    print(stderr)
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: 1000
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: -5
# 150
# GNS FUNCTION: <generate_focal_points>
# Detect:---------------------------------- 1) What is Isabella Rodriguez's daily routine?
# PASS
# === persona/prompt_template/v2/generate_focal_pt_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ["This is Isabella Rodriguez's plan for Monday February 13: wake up and complete the morning routine at 6:00 am, Go to bed around 11:00 pm.\nIsabella Rodriguez is sleeping\nbed is being used\nbed is being used\n1\nusing the bathroom and freshening up\nshower is being used\nmaking her bed and tidying up her room\nbed is being used\nmeditating and practicing mindfulness\nbathroom sink is being used\ngetting dressed in her cafe uniform\ncloset is being used\npreparing a cup of coffee and having breakfast\nkitchen sink is being used\n1\nrefrigerator is being used\nchecking the supplies and placing them on the counter\nsupply store product shelf is being used\nturning on the espresso machine and coffee grinders\ncooking area is being prepared by Isabella Rodriguez\nstarting the music and setting the ambiance\nbed is being used by Isabella Rodriguez\nkitchen sink is being used by Isabella Rodriguez\nwelcoming the first customers and taking their orders\nrefrigerator is being used by Isabella Rodriguez\npreparing food and drink\nrefrigerator is being used by Isabella Rodriguez\ncloset is being organized by Isabella Rodriguez\n1\n", '3']
#
# ~~~ prompt    ----------------------------------------------------
# This is Isabella Rodriguez's plan for Monday February 13: wake up and complete the morning routine at 6:00 am, Go to bed around 11:00 pm.
# Isabella Rodriguez is sleeping
# bed is being used
# bed is being used
# 1
# using the bathroom and freshening up
# shower is being used
# making her bed and tidying up her room
# bed is being used
# meditating and practicing mindfulness
# bathroom sink is being used
# getting dressed in her cafe uniform
# closet is being used
# preparing a cup of coffee and having breakfast
# kitchen sink is being used
# 1
# refrigerator is being used
# checking the supplies and placing them on the counter
# supply store product shelf is being used
# turning on the espresso machine and coffee grinders
# cooking area is being prepared by Isabella Rodriguez
# starting the music and setting the ambiance
# bed is being used by Isabella Rodriguez
# kitchen sink is being used by Isabella Rodriguez
# welcoming the first customers and taking their orders
# refrigerator is being used by Isabella Rodriguez
# preparing food and drink
# refrigerator is being used by Isabella Rodriguez
# closet is being organized by Isabella Rodriguez
# 1
#
#
# Given only the information above, what are 3 most salient high-level questions we can answer about the subjects in the statements?
# 1)
#
# ~~~ output    ----------------------------------------------------
# ["What is Isabella Rodriguez's daily routine?"]
#
# === END ==========================================================
#
#
#
#
# 1 4.850735643704391
# 0.4646328908110486 0.8728063994329557 1.0
# This is Isabella Rodriguez's plan for Monday February 13: wake up and complete the morning routine at 6:00 am, Go to bed around 11:00 pm. 4.833333333333333
# 1.0 1.0 0.6666666666666666
# bed is being used 4.3038529790567575
# 0.709466353181517 0.9830399341553331 0.5
# 1 4.2850858649655335
# 0.0 0.8728063994329557 0.8333333333333334
# starting the music and setting the ambiance 3.7393878089145582
# 0.26150568287548176 0.5362116558256058 1.0
# bed is being used 3.4122551684339
# 0.9262707319358022 0.9830399341553331 0.0
# bed is being used 3.3939609783047624
# 0.8896823516775272 0.9830399341553331 0.0
# 1 3.3783909882924728
# 0.8532769133205443 0.8728063994329557 0.16666666666666666
# shower is being used 3.217118702074874
# 0.7810112080459737 0.8310932549061845 0.16666666666666666
# bathroom sink is being used 2.7902281490371097
# 0.6386351582443334 0.490303523304981 0.5
# preparing food and drink 2.744281465493951
# 0.09683784019206897 0.7875097373548611 0.16666666666666666
# closet is being used 2.6677033787293682
# 0.5685105044766484 0.7944827088303479 0.0
# cooking area is being prepared by Isabella Rodriguez 2.590881998397264
# 0.2949373964563589 0.4811377667230281 0.5
# Isabella Rodriguez is sleeping 2.5539355659037013
# 0.9630429734014049 0.6908046930676663 0.0
# meditating and practicing mindfulness 2.463036613115883
# 0.6739619948170144 0.4864629830135697 0.3333333333333333
# welcoming the first customers and taking their orders 2.3693891407566103
# 0.16221015454788168 0.540539132272001 0.3333333333333333
# refrigerator is being used 2.075478222736838
# 0.4303526997583979 0.6201006242858796 0.0
# kitchen sink is being used 2.059957920765656
# 0.49908534413029587 0.38124952734461376 0.3333333333333333
# refrigerator is being used by Isabella Rodriguez 1.9994223723747222
# 0.06439662439251345 0.43351913117059954 0.3333333333333333
# turning on the espresso machine and coffee grinders 1.9940440599647886
# 0.328537108597944 0.4988140574441612 0.16666666666666666
# bed is being used by Isabella Rodriguez 1.8901865615907674
# 0.22824112786250852 0.5920219992198377 0.0
# closet is being organized by Isabella Rodriguez 1.7968121158020791
# 0.032117614671954973 0.4824733250442561 0.16666666666666666
# preparing a cup of coffee and having breakfast 1.7567413562804288
# 0.53371092535567 0.49662863120086465 0.0
# getting dressed in her cafe uniform 1.6890047591594974
# 0.6034849558545161 0.35130964929963543 0.16666666666666666
# kitchen sink is being used by Isabella Rodriguez 1.5264393557349727
# 0.19514289562460072 0.47628930264089075 0.0
# refrigerator is being used by Isabella Rodriguez 1.3652784321000722
# 0.12944207717654704 0.43351913117059954 0.0
# checking the supplies and placing them on the counter 1.2558149452959724
# 0.39624390966101053 0.1303421079329335 0.3333333333333333
# making her bed and tidying up her room 1.033607410584278
# 0.7451491254071485 0.22034428262690128 0.0
# supply store product shelf is being used 0.9304791353343465
# 0.3623056635141097 0.02755321230354165 0.3333333333333333
# using the bathroom and freshening up 0.7418600844110065
# 0.8170535021553463 0.0 0.16666666666666666
# 1
# This is Isabella Rodriguez's plan for Monday February 13: wake up and complete the morning routine at 6:00 am, Go to bed around 11:00 pm.
# bed is being used
# 1
# starting the music and setting the ambiance
# bed is being used
# bed is being used
# 1
# shower is being used
# bathroom sink is being used
# preparing food and drink
# closet is being used
# cooking area is being prepared by Isabella Rodriguez
# Isabella Rodriguez is sleeping
# meditating and practicing mindfulness
# welcoming the first customers and taking their orders
# refrigerator is being used
# kitchen sink is being used
# refrigerator is being used by Isabella Rodriguez
# turning on the espresso machine and coffee grinders
# bed is being used by Isabella Rodriguez
# closet is being organized by Isabella Rodriguez
# preparing a cup of coffee and having breakfast
# getting dressed in her cafe uniform
# kitchen sink is being used by Isabella Rodriguez
# refrigerator is being used by Isabella Rodriguez
# checking the supplies and placing them on the counter
# making her bed and tidying up her room
# supply store product shelf is being used
# using the bathroom and freshening up
# GNS FUNCTION: <generate_insights_and_evidence>
# Detect:---------------------------------- 1. Isabella Rodriguez has a set morning routine (because of 1, 13, 20, 27).
# 2. Isabella Rodriguez works in a cafe (because of 15, 23).
# 3. Isabella Rodriguez uses various household and cafe amenities throughout the day (because of 2, 5, 6, 8, 9, 11, 12, 16, 17, 18, 19, 24, 25, 28, 29).
# 4. Isabella Rodriguez's day involves a combination of personal and work-related activities (because of 1, 10, 14, 22, 23).
# 5. Isabella Rodriguez is organized and plans her day (because of 1, 26, 27).
# PASS
# === persona/prompt_template/v2/insight_and_evidence_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ["0. 1\n1. This is Isabella Rodriguez's plan for Monday February 13: wake up and complete the morning routine at 6:00 am, Go to bed around 11:00 pm.\n2. bed is being used\n3. 1\n4. starting the music and setting the ambiance\n5. bed is being used\n6. bed is being used\n7. 1\n8. shower is being used\n9. bathroom sink is being used\n10. preparing food and drink\n11. closet is being used\n12. cooking area is being prepared by Isabella Rodriguez\n13. Isabella Rodriguez is sleeping\n14. meditating and practicing mindfulness\n15. welcoming the first customers and taking their orders\n16. refrigerator is being used\n17. kitchen sink is being used\n18. refrigerator is being used by Isabella Rodriguez\n19. turning on the espresso machine and coffee grinders\n20. bed is being used by Isabella Rodriguez\n21. closet is being organized by Isabella Rodriguez\n22. preparing a cup of coffee and having breakfast\n23. getting dressed in her cafe uniform\n24. kitchen sink is being used by Isabella Rodriguez\n25. refrigerator is being used by Isabella Rodriguez\n26. checking the supplies and placing them on the counter\n27. making her bed and tidying up her room\n28. supply store product shelf is being used\n29. using the bathroom and freshening up\n", '5']
#
# ~~~ prompt    ----------------------------------------------------
# Input:
# 0. 1
# 1. This is Isabella Rodriguez's plan for Monday February 13: wake up and complete the morning routine at 6:00 am, Go to bed around 11:00 pm.
# 2. bed is being used
# 3. 1
# 4. starting the music and setting the ambiance
# 5. bed is being used
# 6. bed is being used
# 7. 1
# 8. shower is being used
# 9. bathroom sink is being used
# 10. preparing food and drink
# 11. closet is being used
# 12. cooking area is being prepared by Isabella Rodriguez
# 13. Isabella Rodriguez is sleeping
# 14. meditating and practicing mindfulness
# 15. welcoming the first customers and taking their orders
# 16. refrigerator is being used
# 17. kitchen sink is being used
# 18. refrigerator is being used by Isabella Rodriguez
# 19. turning on the espresso machine and coffee grinders
# 20. bed is being used by Isabella Rodriguez
# 21. closet is being organized by Isabella Rodriguez
# 22. preparing a cup of coffee and having breakfast
# 23. getting dressed in her cafe uniform
# 24. kitchen sink is being used by Isabella Rodriguez
# 25. refrigerator is being used by Isabella Rodriguez
# 26. checking the supplies and placing them on the counter
# 27. making her bed and tidying up her room
# 28. supply store product shelf is being used
# 29. using the bathroom and freshening up
#
#
# What 5 high-level insights can you infer from the above statements? (example format: insight (because of 1, 5, 3))
# 1.
#
# ~~~ output    ----------------------------------------------------
# {'Isabella Rodriguez has a set morning routine': [1, 13, 20, 27], 'Isabella Rodriguez works in a cafe': [15, 23], 'Isabella Rodriguez uses various household and cafe amenities throughout the day': [2, 5, 6, 8, 9, 11, 12, 16, 17, 18, 19, 24, 25, 28, 29], "Isabella Rodriguez's day involves a combination of personal and work-related activities": [1, 10, 14, 22, 23], 'Isabella Rodriguez is organized and plans her day': [1, 26, 27]}
#
# === END ==========================================================
#
#
#
#
# {'Isabella Rodriguez has a set morning routine': [1, 13, 20, 27], 'Isabella Rodriguez works in a cafe': [15, 23], 'Isabella Rodriguez uses various household and cafe amenities throughout the day': [2, 5, 6, 8, 9, 11, 12, 16, 17, 18, 19, 24, 25, 28, 29], "Isabella Rodriguez's day involves a combination of personal and work-related activities": [1, 10, 14, 22, 23], 'Isabella Rodriguez is organized and plans her day': [1, 26, 27]}
# GNS FUNCTION: <generate_action_event_triple>
# Detect:---------------------------------- (Isabella Rodriguez, have, morning routine)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 18
#      16 # Read and print the output line by line in real time
#      17 while True:
# ---> 18     output_line = process.stdout.readline()
#      19     if output_line == '' and process.poll() is not None:
#      20         break
#
# KeyboardInterrupt:
