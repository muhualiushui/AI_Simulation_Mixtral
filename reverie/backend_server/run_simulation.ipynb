# %%
i=3
# for i in range(2,3):
# !echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/03_20/output$i"
# Out:
# ^C

# %%
import subprocess

repeat_count = 5

command = "4_19_test_2\n4_20_test_C"
for _ in range(repeat_count):
    command += "\nrun 3000"
command += "\nfin"

process = subprocess.Popen(['python3', 'reverie.py'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Send the command to the subprocess
process.stdin.write(command)
process.stdin.close()

# Read and print the output line by line in real time
while True:
    output_line = process.stdout.readline()
    if output_line == '' and process.poll() is not None:
        break
    if output_line:
        print(output_line.strip())

# Check for any errors
stderr = process.stderr.read()
if stderr:
    print(stderr)
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: 3000
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 7
# CHAT GPT PROMPT
# """
# Here is a brief description of Isabella Rodriguez.
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., brushing teeth, making bed) and 10 is extremely poignant (e.g., a break up, college acceptance), rate the likely poignancy of the following event for Isabella Rodriguez.
#
# Event: Isabella Rodriguez is conversing about Isabella Rodriguez and Klaus Mueller <fill in> planning a Valentine's Day party with a photo booth, dance segment, and heart-themed decorations
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 9
# CHAT GPT PROMPT
# """
# Here is a brief description of Isabella Rodriguez.
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., routine morning greetings) and 10 is extremely poignant (e.g., a conversation about breaking up, a fight), rate the likely poignancy of the following conversation for Isabella Rodriguez.
#
# Conversation:
# conversing about Isabella Rodriguez and Klaus Mueller <fill in> planning a Valentine's Day party with a photo booth, dance segment, and heart-themed decorations
#
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# ---- repeat count:
# 0 8
# 8
# ~~~~
# ---- repeat count:
# 1 8
# 8
# ~~~~
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 7
# CHAT GPT PROMPT
# """
# Here is a brief description of Isabella Rodriguez.
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., brushing teeth, making bed) and 10 is extremely poignant (e.g., a break up, college acceptance), rate the likely poignancy of the following event for Isabella Rodriguez.
#
# Event: Klaus Mueller is conversing about Isabella Rodriguez and Klaus Mueller <fill in> planning a Valentine's Day party with a photo booth, dance segment, and heart-themed decorations
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 58
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 7
# CHAT GPT PROMPT
# """
# Here is a brief description of Klaus Mueller.
# Name: Klaus Mueller
# Age: 20
# Innate traits: kind, inquisitive, passionate
# Learned traits: Klaus Mueller is a student at Oak Hill College studying sociology. He is passionate about social justice and loves to explore different perspectives.
# Currently: Klaus Mueller is discussing Valentine's Day party with Isabella Rodriguez in morning and writing a research paper on the effects of gentrification in low-income communities in afternoon at Hobbs Cafe
# Lifestyle: Klaus Mueller goes to bed around 11pm, awakes up around 7am, eats dinner around 5pm.
# Daily plan requirement: Klaus Mueller goes to the library at Oak Hill College early in the morning, spends his days writing, and eats at Hobbs Cafe.
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., brushing teeth, making bed) and 10 is extremely poignant (e.g., a break up, college acceptance), rate the likely poignancy of the following event for Klaus Mueller.
#
# Event: Klaus Mueller is conversing about Isabella Rodriguez and Klaus Mueller <fill in> planning a Valentine's Day party with a photo booth, dance segment, and heart-themed decorations
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# LLM ERROR
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 9
# CHAT GPT PROMPT
# """
# Here is a brief description of Klaus Mueller.
# Name: Klaus Mueller
# Age: 20
# Innate traits: kind, inquisitive, passionate
# Learned traits: Klaus Mueller is a student at Oak Hill College studying sociology. He is passionate about social justice and loves to explore different perspectives.
# Currently: Klaus Mueller is discussing Valentine's Day party with Isabella Rodriguez in morning and writing a research paper on the effects of gentrification in low-income communities in afternoon at Hobbs Cafe
# Lifestyle: Klaus Mueller goes to bed around 11pm, awakes up around 7am, eats dinner around 5pm.
# Daily plan requirement: Klaus Mueller goes to the library at Oak Hill College early in the morning, spends his days writing, and eats at Hobbs Cafe.
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., routine morning greetings) and 10 is extremely poignant (e.g., a conversation about breaking up, a fight), rate the likely poignancy of the following conversation for Klaus Mueller.
#
# Conversation:
# conversing about Isabella Rodriguez and Klaus Mueller <fill in> planning a Valentine's Day party with a photo booth, dance segment, and heart-themed decorations
#
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# ---- repeat count:
# 0 8
# 8
# ~~~~
# ---- repeat count:
# 1 7
# 7
# ~~~~
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 7
# CHAT GPT PROMPT
# """
# Here is a brief description of Klaus Mueller.
# Name: Klaus Mueller
# Age: 20
# Innate traits: kind, inquisitive, passionate
# Learned traits: Klaus Mueller is a student at Oak Hill College studying sociology. He is passionate about social justice and loves to explore different perspectives.
# Currently: Klaus Mueller is discussing Valentine's Day party with Isabella Rodriguez in morning and writing a research paper on the effects of gentrification in low-income communities in afternoon at Hobbs Cafe
# Lifestyle: Klaus Mueller goes to bed around 11pm, awakes up around 7am, eats dinner around 5pm.
# Daily plan requirement: Klaus Mueller goes to the library at Oak Hill College early in the morning, spends his days writing, and eats at Hobbs Cafe.
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., brushing teeth, making bed) and 10 is extremely poignant (e.g., a break up, college acceptance), rate the likely poignancy of the following event for Klaus Mueller.
#
# Event: Isabella Rodriguez is conversing about Isabella Rodriguez and Klaus Mueller <fill in> planning a Valentine's Day party with a photo booth, dance segment, and heart-themed decorations
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# aldhfoaf/????
# 2999
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2998
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2997
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2996
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2995
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2994
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2993
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2992
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2991
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2990
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2989
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2988
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2987
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2986
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2985
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2984
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2983
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2982
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2981
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2980
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2979
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2978
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2977
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2976
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2975
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2974
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2973
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2972
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2971
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2970
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2969
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2968
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2967
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2966
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2965
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2964
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2963
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2962
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2961
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2960
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2959
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2958
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2957
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2956
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2955
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2954
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2953
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2952
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2951
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2950
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2949
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2948
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2947
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2946
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2945
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2944
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2943
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2942
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2941
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2940
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2939
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2938
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2937
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# DEBUG LJSDLFSKJF
# ['sleeping', 540]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (1) Maria is getting out of bed)', 5]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (brushing her teeth)', 5]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (taking a shower)', 10]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (getting dressed)', 10]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (making coffee)', 5]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (packing her bag for the day)', 10]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (checking her phone and social media)', 10]
# ['[(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (heading out the door)', 5]
# ['[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe (1) Maria is ordering breakfast at the counter)', 5]
# ['[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe (eating her breakfast)', 40]
# ['[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe (chatting with other customers at Hobbs Cafe)', 15]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (1) Maria is taking out her physics textbook and notebook)', 5]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (reviewing her previous notes)', 10]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (working on practice problems)', 20]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (looking up concepts she is struggling with in the textbook)', 10]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (jotting down questions she wants to ask the professor)', 5]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (taking a short break to stretch and grab a snack)', 5]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (reviewing her work and preparing for the next session)', 5]
# ['[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe (1) Maria is reviewing her physics textbook and notes)', 15]
# ['[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe (working on physics practice problems)', 15]
# ['[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe (taking a short break to get a snack and drink)', 5]
# ['[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe (discussing a physics concept with a classmate)', 15]
# ['[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe (summarizing key points from her study session)', 10]
# ['[(ID:vbOMYz) Monday February 13 -- 01:00 PM] Activity: Maria is leaving Hobbs Cafe and heading to the college campus', 60]
# ['[(ID:iiQ7r1) Monday February 13 -- 02:00 PM] Activity: Maria is attending a physics lecture on campus', 60]
# ['[(ID:BCcYFx) Monday February 13 -- 03:00 PM] Activity: Maria is attending a study group session for her physics class on campus', 60]
# ['[(ID:rlZkTV) Monday February 13 -- 04:00 PM] Activity: Maria is returning to Hobbs Cafe to continue studying physics', 60]
# ['[(ID:zPrc6s) Monday February 13 -- 05:00 PM] Activity: Maria is enjoying a snack and relaxing at Hobbs Cafe', 60]
# ['[(ID:vicVJt) Monday February 13 -- 06:00 PM] Activity: Maria is preparing dinner at Hobbs Cafe', 60]
# ['Maria is eating dinner', 60]
# ['[(ID:76jdEl) Monday February 13 -- 08:00 PM] Activity: Maria is returning to Hobbs Cafe and preparing to start her Twitch stream', 60]
# ['[(ID:ofnUDQ) Monday February 13 -- 09:00 PM] Activity: Maria is streaming on Twitch', 60]
# ['[(ID:7DOHBj) Monday February 13 -- 10:00 PM] Activity: Maria is preparing for bed', 60]
# ['[(ID:fekZHJ) Monday February 13 -- 00:00 AM] Activity: Maria is sleeping\n[(ID:tBRjGm) Monday February 13 -- 01:00 AM] Activity: Maria is sleeping\n[(ID:xr7qxG) Monday February 13 -- 02:00 AM] Activity: Maria is sleeping\n[(ID:LVbWAB) Monday February 13 -- 03:00 AM] Activity: Maria is sleeping\n[(ID:P1tUxR) Monday February 13 -- 04:00 AM] Activity: Maria is sleeping\n[(ID:djeNvA) Monday February 13 -- 05:00 AM] Activity: Maria is sleeping\n[(ID:4eL9RK) Monday February 13 -- 06:00 AM] Activity: Maria is sleeping\n[(ID:etYbgm) Monday February 13 -- 07:00 AM] Activity: Maria is sleeping\n[(ID:oLYBmu) Monday February 13 -- 08:00 AM] Activity: Maria is sleeping\n[(ID:suSfM8) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine\n[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe\n[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe\n[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe\n[(ID:vbOMYz) Monday February 13 -- 01:00 PM] Activity: Maria is leaving Hobbs Cafe and heading to the college campus\n[(ID:iiQ7r1) Monday February 13 -- 02:00 PM] Activity: Maria is attending a physics lecture on campus\n[(ID:BCcYFx) Monday February 13 -- 03:00 PM] Activity: Maria is attending a study group session for her physics class on campus\n[(ID:rlZkTV) Monday February 13 -- 04:00 PM] Activity: Maria is returning to Hobbs Cafe to continue studying physics\n[(ID:zPrc6s) Monday February 13 -- 05:00 PM] Activity: Maria is enjoying a snack and relaxing at Hobbs Cafe\n[(ID:vicVJt) Monday February 13 -- 06:00 PM] Activity: Maria is preparing dinner at Hobbs Cafe\n[(ID:Hd65CZ) Monday February 13 -- 07:00 PM] Activity: Maria is eating dinner\n[(ID:76jdEl) Monday February 13 -- 08:00 PM] Activity: Maria is returning to Hobbs Cafe and preparing to start her Twitch stream\n[(ID:ofnUDQ) Monday February 13 -- 09:00 PM] Activity: Maria is streaming on Twitch\n[(ID:7DOHBj) Monday February 13 -- 10:00 PM] Activity: Maria is preparing for bed\n[(ID:j20bfM) Monday February 13 -- 11:00 PM] Activity: Maria is sleeping', 60]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# 15
# 52
# Maria Lopez
# ------
# GNS FUNCTION: <generate_action_sector>
# Detect:---------------------------------- For looking up concepts she is struggling with in the textbook, Maria Lopez should go to the following area: {Oak Hill College}
# type 2 error in line 602```````````````````````````````````````````````````````````
# Detect:---------------------------------- Dorm for Oak Hill College}
# PASS
# DEBUG Giorgio Rossi's apartment ------ Dorm for Oak Hill College
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen, Klaus Mueller's room, Wolfgang Schulz's room", 'Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen, Klaus Mueller's room, Wolfgang Schulz's room", '\nMaria Lopez spends at least 3 hours a day Twitch streaming or gaming.', "Oak Hill College, Dorm for Oak Hill College, The Willows Market and Pharmacy, Harvey Oak Supply Store, Johnson Park, The Rose and Crown Pub, Hobbs Cafe, Ryan Park's apartment, Giorgio Rossi's apartment, Isabella Rodriguez's apartment, Carlos Gomez's apartment", 'Maria Lopez', '[', 'looking up concepts she is struggling with in the textbook', 'Maria Lopez']
#
# ~~~ prompt    ----------------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Maria Lopez lives in {Dorm for Oak Hill College} that has garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen, Klaus Mueller's room, Wolfgang Schulz's room.
# Maria Lopez is currently in {Dorm for Oak Hill College} that has garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen, Klaus Mueller's room, Wolfgang Schulz's room.
# Maria Lopez spends at least 3 hours a day Twitch streaming or gaming.
# Area options: {Oak Hill College, Dorm for Oak Hill College, The Willows Market and Pharmacy, Harvey Oak Supply Store, Johnson Park, The Rose and Crown Pub, Hobbs Cafe, Ryan Park's apartment, Giorgio Rossi's apartment, Isabella Rodriguez's apartment, Carlos Gomez's apartment}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Maria Lopez is [. For looking up concepts she is struggling with in the textbook, Maria Lopez should go to the following area: {
#
# ~~~ output    ----------------------------------------------------
# Dorm for Oak Hill College
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_arena>
# Detect:---------------------------------- Maria Lopez's room}
# PASS
# === persona/prompt_template/v1/action_location_object_vMar12.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen", 'Maria Lopez', '[', 'looking up concepts she is struggling with in the textbook', 'Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen"]
#
# ~~~ prompt    ----------------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# For cooking, Jane Anderson should go to which area in Jane Anderson's house:
# Answer: {kitchen}
#
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# For getting coffee, Tom Watson should go to which area in Hobbs Cafe:
# Answer: {cafe}
#
# Now your turn:
# Maria Lopez is going to Dorm for Oak Hill College that has the following areas: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# Maria Lopez is [. For looking up concepts she is struggling with in the textbook, Maria Lopez should go to which area in Dorm for Oak Hill College:
# Answer: {
#
# ~~~ output    ----------------------------------------------------
# Maria Lopez's room
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
# Maria Lopez's room
# Maria Lopez's room
# Identified?????????????????????????????????????/
# Maria Lopez's room
# Maria Lopez's room
# Detect:---------------------------------- desk
# PASS
# Identified?????????????????????????????????????/
# Maria Lopez's room
# Maria Lopez's room
# === persona/prompt_template/v1/action_object_v2.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['looking up concepts she is struggling with in the textbook', 'closet, desk, bed, computer, blackboard']
#
# ~~~ prompt    ----------------------------------------------------
# Current activity: sleep in bed
# Objects available: {bed, easel, closet, painting}
# Pick ONE most relevant object from the objects available: bed
# ---
# Current activity: painting
# Objects available: {easel, closet, sink, microwave}
# Pick ONE most relevant object from the objects available: easel
# ---
# Current activity: cooking
# Objects available: {stove, sink, fridge, counter}
# Pick ONE most relevant object from the objects available: stove
# ---
# Current activity: watch TV
# Objects available: {couch, TV, remote, coffee table}
# Pick ONE most relevant object from the objects available: TV
# ---
# Current activity: study
# Objects available: {desk, computer, chair, bookshelf}
# Pick ONE most relevant object from the objects available: desk
# ---
# Current activity: talk on the phone
# Objects available: {phone, charger, bed, nightstand}
# Pick ONE most relevant object from the objects available: phone
# ---
# Current activity: looking up concepts she is struggling with in the textbook
# Objects available: {closet, desk, bed, computer, blackboard}
# Pick ONE most relevant object from the objects available:
#
# ~~~ output    ----------------------------------------------------
# desk
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: looking up concepts she is struggling with in the textbook
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# GNS FUNCTION: <generate_action_event_triple>
# Detect:---------------------------------- (Maria Lopez, look up, concepts)
# Detect:---------------------------------- (Maria Lopez, look up, concepts)
# Detect:---------------------------------- (Maria Lopez, look up, concepts)
# Detect:---------------------------------- (Maria Lopez, look up, concepts)
# Detect:---------------------------------- (Maria Lopez, look up, concepts)
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Maria Lopez', 'looking up concepts she is struggling with in the textbook', 'Maria Lopez']
#
# ~~~ prompt    ----------------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: Maria Lopez is looking up concepts she is struggling with in the textbook.
# Output: (Maria Lopez,
#
# ~~~ output    ----------------------------------------------------
# ('Maria Lopez', 'Maria Lopez', 'is')
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_act_obj_desc>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 6
# CHAT GPT PROMPT
# """
# Task: We want to understand the state of an object that is being used by someone.
#
# ---
# Example 1:
# Kelly is writing on the desk.
# Desk is: being used by Kelly.
#
# Example 2:
# Jason is fixing the TV.
# TV is: being fixed by Jason.
#
# Example 3:
# Jessica is sleeping on the bed.
# Bed is: being used by Jessica.
# ---
#
# Now, We want to know about desk's state.
# Maria Lopez is [(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe (looking up concepts she is struggling with in the textbook) with the desk.
# desk is:
# """
# Output the response to the prompt above in json. The output should ONLY contain the phrase that should go in <fill in>.
# Example output json:
# {"output": "being fixed"}
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: being used by Maria Lopez
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# GNS FUNCTION: <generate_act_obj_event_triple>
# Detect:---------------------------------- Input: Sam Johnson is eating breakfast.
# Output: (Sam Johnson, eat, breakfast)
#
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
#
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, sleep, -)
#
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
#
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
#
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
#
# Input: desk is being used by Maria Lopez.
# Output: (desk, use, Maria Lopez)
# Detect:---------------------------------- (desk, be used by, Maria Lopez)
# Detect:---------------------------------- (desk, be used by, Maria Lopez)
# Detect:---------------------------------- Input: desk is being used by Maria Lopez.
# Output: (desk, use, Maria Lopez)
# Detect:---------------------------------- (desk, use, Maria Lopez)
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['desk', 'being used by Maria Lopez', 'desk']
#
# ~~~ prompt    ----------------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: desk is being used by Maria Lopez.
# Output: (desk,
#
# ~~~ output    ----------------------------------------------------
# ('desk', 'desk', 'is')
#
# === END ==========================================================
#
#
#
#
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# aldhfoaf/????
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2936
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2935
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2934
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2933
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2932
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2931
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2930
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2929
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2928
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2927
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2926
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2925
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2924
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2923
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2922
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2921
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# Maria Lopez persona.scratch.importance_trigger_curr:: 142
# 150
# Klaus Mueller persona.scratch.importance_trigger_curr:: 90
# 150
# 2920
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 55
# 150
# GNS FUNCTION: <generate_planning_thought_on_convo>
# Detect:---------------------------------- Isabella Rodriguez needs to remember to order heart-shaped balloons and streamers to really set the mood for the Valentine's Day party.
# PASS
# === persona/prompt_template/v2/planning_thought_on_convo_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ...
# ['[(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine (doing a quick yoga routine)', 10]
# ['[(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine (packing her lunch for the day)', 10]
# ['[(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine (locking up her apartment and heading to the cafe)', 5]
# ['[(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day (1) Isabella is unlocking the cafe and turning on the lights)', 5]
# ['[(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day (turning on the coffee machines and preparing the pastries)', 10]
# ['[(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day (counting the cash drawer and preparing the register)', 10]
# ["[(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day (putting out the cafe's menu and setting up the tables and chairs)", 15]
# ['[(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day (checking the inventory and making a list of supplies to order)', 10]
# ['[(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day (greeting the first customers and welcoming them to the cafe)', 10]
# ['[(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe (1) Isabella is turning on the cafe equipment and checking inventory)', 10]
# ['[(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe (preparing the cafe counter and setting up the register)', 10]
# ['[(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe (greeting and welcoming customers as they arrive)', 15]
# ['[(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe (taking orders and processing payments)', 20]
# ['[(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe (ensuring the cafe is clean and tidy)', 5]
# ['[(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter (1) Isabella is greeting customers and welcoming them to the cafe)', 5]
# ['[(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter (taking customer orders)', 20]
# ['[(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter (preparing and serving coffee, tea, and light snacks to customers)', 20]
# ['[(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter (checking in with customers to ensure they are satisfied)', 10]
# ['[(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter (cleaning and preparing the counter for the next hour)', 5]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (1) Isabella is taking orders from customers)', 10]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (preparing and serving coffee and food items)', 15]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (checking on customer satisfaction)', 5]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (restocking supplies)', 5]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (ringing up customers)', 10]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (wiping down tables and counters)', 5]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (responding to customer questions)', 5]
# ['[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (preparing the next set of orders)', 5]
# ['[(ID:3f8Ypy) Monday February 13 -- 11:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (1) Isabella is taking orders from customers)', 10]
# ['[(ID:3f8Ypy) Monday February 13 -- 11:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (preparing and serving drinks)', 10]
# ['[(ID:3f8Ypy) Monday February 13 -- 11:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (preparing and serving food items)', 15]
# ['[ (on the way to ringing up customers at the cash register)', 0]
# ["[ (conversing about Isabella Rodriguez and Klaus Mueller <fill in> planning a Valentine's Day party with a photo booth, dance segment, and heart-themed decorations)", 13]
# ['[(ID:3f8Ypy) Monday February 13 -- 11:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (tidying up the counter area)', 10]
# ['[(ID:3f8Ypy) Monday February 13 -- 11:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter (responding to customer inquiries)', 5]
# ['[(ID:9wRUa0) Monday February 13 -- 12:00 PM] Activity: Isabella is taking her lunch break (1) Isabella is preparing her lunch in the cafe kitchen)', 10]
# ['[(ID:9wRUa0) Monday February 13 -- 12:00 PM] Activity: Isabella is taking her lunch break (eating her lunch at the counter)', 20]
# ['[(ID:9wRUa0) Monday February 13 -- 12:00 PM] Activity: Isabella is taking her lunch break (checking her schedule and to-do list for the day)', 10]
# ['[(ID:9wRUa0) Monday February 13 -- 12:00 PM] Activity: Isabella is taking her lunch break (taking a short break, checking her phone and social media)', 10]
# ['[(ID:9wRUa0) Monday February 13 -- 12:00 PM] Activity: Isabella is taking her lunch break (cleaning up and getting ready to return to work)', 7]
# ['[(ID:CiWmlj) Monday February 13 -- 01:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (1) Isabella is greeting customers and welcoming them to the cafe)', 5]
# ['[(ID:CiWmlj) Monday February 13 -- 01:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (taking customer orders)', 10]
# ['[(ID:CiWmlj) Monday February 13 -- 01:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (preparing and serving the customer orders)', 15]
# ['[(ID:CiWmlj) Monday February 13 -- 01:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (refilling customer drinks)', 5]
# ['[(ID:CiWmlj) Monday February 13 -- 01:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (clearing used dishes and cleaning tables)', 10]
# ['[(ID:CiWmlj) Monday February 13 -- 01:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (checking on customer satisfaction)', 5]
# ['[(ID:CiWmlj) Monday February 13 -- 01:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (restocking and organizing supplies)', 10]
# ['[(ID:fdTtw3) Monday February 13 -- 02:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (1) Isabella is serving customers at the cafe counter)', 10]
# ['[(ID:fdTtw3) Monday February 13 -- 02:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (taking orders from customers)', 10]
# ['[(ID:fdTtw3) Monday February 13 -- 02:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (preparing drinks for customers)', 10]
# ['[(ID:fdTtw3) Monday February 13 -- 02:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (delivering orders to customers)', 10]
# ['[(ID:fdTtw3) Monday February 13 -- 02:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (cleaning the counter and preparing for the next batch of customers)', 10]
# ['[(ID:fdTtw3) Monday February 13 -- 02:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter (checking inventory and restocking supplies)', 10]
# ['[(ID:Zg9TeJ) Monday February 13 -- 03:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter', 60]
# ['[(ID:hiGjEh) Monday February 13 -- 04:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter', 60]
# ['[(ID:0AQMru) Monday February 13 -- 05:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter', 60]
# ['[(ID:ezrTtK) Monday February 13 -- 06:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter', 60]
# ['[(ID:KuyzYY) Monday February 13 -- 07:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter', 60]
# ['[(ID:PJyiVD) Monday February 13 -- 08:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter', 60]
# ['[(ID:l4D8ww) Monday February 13 -- 09:00 PM] Activity: Isabella is continuing to serve customers at the cafe counter', 60]
# ['[(ID:nZLz4U) Monday February 13 -- 10:00 PM] Activity: Isabella is preparing to close Hobbs Cafe for the day', 60]
# ['[(ID:FOEAdx) Monday February 13 -- 11:00 PM] Activity: Isabella is going to bed', 60]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# 50
# 120
# Isabella Rodriguez
# ------
# GNS FUNCTION: <generate_action_sector>
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# PASS
# DEBUG Harvey Oak Supply Store ------ Isabella Rodriguez's apartment
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room, bathroom', 'Isabella Rodriguez', 'Hobbs Cafe', 'cafe', '\nIsabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.', "Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment, Giorgio Rossi's apartment", 'Isabella Rodriguez', '[', 'checking on customer satisfaction', 'Isabella Rodriguez']
#
# ~~~ prompt    ----------------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Isabella Rodriguez lives in {Isabella Rodriguez's apartment} that has main room, bathroom.
# Isabella Rodriguez is currently in {Hobbs Cafe} that has cafe.
# Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Area options: {Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment, Giorgio Rossi's apartment}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Isabella Rodriguez is [. For checking on customer satisfaction, Isabella Rodriguez should go to the following area: {
#
# ~~~ output    ----------------------------------------------------
# Isabella Rodriguez's apartment
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_arena>
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# === persona/prompt_template/v1/action_location_object_vMar12.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room, bathroom', 'Isabella Rodriguez', '[', 'checking on customer satisfaction', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room, bathroom']
#
# ~~~ prompt    ----------------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {main room, bathroom}
# For cooking, Jane Anderson should go to which area in Jane Anderson's house:
# Answer: {kitchen}
#
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {main room, bathroom}
# For getting coffee, Tom Watson should go to which area in Hobbs Cafe:
# Answer: {cafe}
#
# Now your turn:
# Isabella Rodriguez is going to Isabella Rodriguez's apartment that has the following areas: {main room, bathroom}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {main room, bathroom}
# Isabella Rodriguez is [. For checking on customer satisfaction, Isabella Rodriguez should go to which area in Isabella Rodriguez's apartment:
# Answer: {
#
# ~~~ output    ----------------------------------------------------
# kitchen
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
# kitchen
# kitchen
# Error.
