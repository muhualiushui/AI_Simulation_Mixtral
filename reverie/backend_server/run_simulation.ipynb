# %%
i=3
# for i in range(2,3):
# !echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/03_20/output$i"
# Out:
# ^C

# %%
import subprocess

repeat_count = 5

command = "Discussion_test_3_person\n4_19_test"
for _ in range(repeat_count):
    command += "\nrun 1000"
command += "\nfin"

process = subprocess.Popen(['python3', 'reverie.py'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Send the command to the subprocess
process.stdin.write(command)
process.stdin.close()

# Read and print the output line by line in real time
while True:
    output_line = process.stdout.readline()
    if output_line == '' and process.poll() is not None:
        break
    if output_line:
        print(output_line.strip())

# Check for any errors
stderr = process.stderr.read()
if stderr:
    print(stderr)
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: 1000
# GNS FUNCTION: <generate_wake_up_hour>
# Detect:---------------------------------- 6
# PASS
# === persona/prompt_template/v2/wake_up_hour_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Isabella']
#
# ~~~ prompt    ----------------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Isabella's wake up hour (digit only):
#
# ~~~ output    ----------------------------------------------------
# 6
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_first_daily_plan>
# Detect:---------------------------------- 1) wake up and complete the morning routine at 6:00 am, 2) open Hobbs Cafe at 8:00 am, 3) work at the counter until 8:00 pm, 4) close the cafe at 8:00 pm, 5) go to bed around 11:00 pm.
# PASS
# === persona/prompt_template/v2/daily_planning_v6.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Monday February 13', 'Isabella', '6:00 am']
#
# ~~~ prompt    ----------------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Today is Monday February 13. Here is Isabella's plan today in broad-strokes with the time of the day. Nothing other than a list for plan. e.g.,1) have a lunch at 12:00 pm, 2) watch TV from 7 to 8 pm:1) wake up and complete the morning routine at 6:00 am, 2)
#
# ~~~ output    ----------------------------------------------------
# ['wake up and complete the morning routine at 6:00 am', 'wake up and complete the morning routine at 6:00 am', 'open Hobbs Cafe at 8:00 am', 'work at the counter until 8:00 pm', 'close the cafe at 8:00 pm', 'go to bed around 11:00 pm']
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_hourly_schedule>
# Detect:---------------------------------- [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine.
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:rkLPCY) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:kYg4Cf) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:DYN6sX) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:9tExQf) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:fzpujM) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:fidtQi) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm", '', '[(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:rkLPCY) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:kYg4Cf) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:DYN6sX) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:9tExQf) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:fzpujM) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:fidtQi) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is
#
# ~~~ output    ----------------------------------------------------
# [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine
#
# === END ==========================================================
#
#
#
#
# Detect:---------------------------------- [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day.
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:7QX7hW) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:D5qizp) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:Olz2xI) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:i5XFYD) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:s5deLR) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:a6LrwW) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:CGaSSW) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm", '', '[(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:7QX7hW) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:D5qizp) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:Olz2xI) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:i5XFYD) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:s5deLR) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:a6LrwW) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:CGaSSW) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is
#
# ~~~ output    ----------------------------------------------------
# [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day
#
# === END ==========================================================
#
#
#
#
# Detect:---------------------------------- [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe.
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:UhqNDL) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:l6EtIQ) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:QoHJ38) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:KrGm3t) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:9ZiG8z) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:vL90Pe) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:36ZPJe) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine\n[(ID:qpMGBN) Monday February 13 -- 07:00 AM] Activity: Isabella is [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm", '', '[(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:UhqNDL) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:l6EtIQ) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:QoHJ38) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:KrGm3t) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:9ZiG8z) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:vL90Pe) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:36ZPJe) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine
# [(ID:qpMGBN) Monday February 13 -- 07:00 AM] Activity: Isabella is [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is
#
# ~~~ output    ----------------------------------------------------
# [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe
#
# === END ==========================================================
#
#
#
#
# Detect:---------------------------------- [(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter.
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:yUHvPR) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:LZlZGe) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:HkvH4Z) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:HH268d) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:4SL2j6) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:np3jxh) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:ZXCsBM) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine\n[(ID:mCEEb9) Monday February 13 -- 07:00 AM] Activity: Isabella is [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day\n[(ID:L6jEcK) Monday February 13 -- 08:00 AM] Activity: Isabella is [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm", '', '[(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:yUHvPR) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:LZlZGe) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:HkvH4Z) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:HH268d) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:4SL2j6) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:np3jxh) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:ZXCsBM) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine
# [(ID:mCEEb9) Monday February 13 -- 07:00 AM] Activity: Isabella is [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day
# [(ID:L6jEcK) Monday February 13 -- 08:00 AM] Activity: Isabella is [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is
#
# ~~~ output    ----------------------------------------------------
# [(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter
#
# === END ==========================================================
#
#
#
#
# Detect:---------------------------------- [(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter.
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:tfISbD) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:aQDJT4) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:krorMN) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:sfjaim) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:xZUucN) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:tuLXjK) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:IrfeMe) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine\n[(ID:QGWiRw) Monday February 13 -- 07:00 AM] Activity: Isabella is [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day\n[(ID:ljEn6c) Monday February 13 -- 08:00 AM] Activity: Isabella is [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe\n[(ID:h8nILw) Monday February 13 -- 09:00 AM] Activity: Isabella is [(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm", '', '[(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:tfISbD) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:aQDJT4) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:krorMN) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:sfjaim) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:xZUucN) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:tuLXjK) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:IrfeMe) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine
# [(ID:QGWiRw) Monday February 13 -- 07:00 AM] Activity: Isabella is [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day
# [(ID:ljEn6c) Monday February 13 -- 08:00 AM] Activity: Isabella is [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe
# [(ID:h8nILw) Monday February 13 -- 09:00 AM] Activity: Isabella is [(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is
#
# ~~~ output    ----------------------------------------------------
# [(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter
#
# === END ==========================================================
#
#
#
#
# Detect:---------------------------------- [(ID:3f8Ypy) Monday February 13 -- 11:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter.
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:Hgyi1Q) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:94FhLZ) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:DFINee) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:92Gqne) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:e2CLu7) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:gmZN47) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:8y7Zij) Monday February 13 -- 06:00 AM] Activity: Isabella is [(ID:k04slx) Monday February 13 -- 06:00 AM] Activity: Isabella is waking up and completing her morning routine\n[(ID:tz0Vkx) Monday February 13 -- 07:00 AM] Activity: Isabella is [(ID:cZUD78) Monday February 13 -- 07:00 AM] Activity: Isabella is opening Hobbs Cafe for the day\n[(ID:zAS5xW) Monday February 13 -- 08:00 AM] Activity: Isabella is [(ID:SWTAtz) Monday February 13 -- 08:00 AM] Activity: Isabella is working at the counter of Hobbs Cafe\n[(ID:r1iZX9) Monday February 13 -- 09:00 AM] Activity: Isabella is [(ID:NvTBDU) Monday February 13 -- 09:00 AM] Activity: Isabella is serving customers at the cafe counter\n[(ID:6KYtQ2) Monday February 13 -- 10:00 AM] Activity: Isabella is [(ID:OFVFHq) Monday February 13 -- 10:00 AM] Activity: Isabella is continuing to serve customers at the cafe counter\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) wake up and complete the morning routine at 6:00 am, 3) open Hobbs Cafe at 8:00 am, 4) work at the counter until 8:00 pm, 5) close the cafe at 8:00 pm, 6) go to bed around 11:00 pm", '', '[(ID:3f8Ypy) Monday February 13 -- 11:00 AM] Activity: Isabella is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# ...
# ['[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe (1) Maria is ordering breakfast at the counter)', 5]
# ['[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe (eating her breakfast)', 40]
# ['[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe (chatting with other customers at Hobbs Cafe)', 15]
# ['[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe', 60]
# ['[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe', 60]
# ['[(ID:vbOMYz) Monday February 13 -- 01:00 PM] Activity: Maria is leaving Hobbs Cafe and heading to the college campus', 60]
# ['[(ID:iiQ7r1) Monday February 13 -- 02:00 PM] Activity: Maria is attending a physics lecture on campus', 60]
# ['[(ID:BCcYFx) Monday February 13 -- 03:00 PM] Activity: Maria is attending a study group session for her physics class on campus', 60]
# ['[(ID:rlZkTV) Monday February 13 -- 04:00 PM] Activity: Maria is returning to Hobbs Cafe to continue studying physics', 60]
# ['[(ID:zPrc6s) Monday February 13 -- 05:00 PM] Activity: Maria is enjoying a snack and relaxing at Hobbs Cafe', 60]
# ['[(ID:vicVJt) Monday February 13 -- 06:00 PM] Activity: Maria is preparing dinner at Hobbs Cafe', 60]
# ['Maria is eating dinner', 60]
# ['[(ID:76jdEl) Monday February 13 -- 08:00 PM] Activity: Maria is returning to Hobbs Cafe and preparing to start her Twitch stream', 60]
# ['[(ID:ofnUDQ) Monday February 13 -- 09:00 PM] Activity: Maria is streaming on Twitch', 60]
# ['[(ID:7DOHBj) Monday February 13 -- 10:00 PM] Activity: Maria is preparing for bed', 60]
# ['[(ID:fekZHJ) Monday February 13 -- 00:00 AM] Activity: Maria is sleeping\n[(ID:tBRjGm) Monday February 13 -- 01:00 AM] Activity: Maria is sleeping\n[(ID:xr7qxG) Monday February 13 -- 02:00 AM] Activity: Maria is sleeping\n[(ID:LVbWAB) Monday February 13 -- 03:00 AM] Activity: Maria is sleeping\n[(ID:P1tUxR) Monday February 13 -- 04:00 AM] Activity: Maria is sleeping\n[(ID:djeNvA) Monday February 13 -- 05:00 AM] Activity: Maria is sleeping\n[(ID:4eL9RK) Monday February 13 -- 06:00 AM] Activity: Maria is sleeping\n[(ID:etYbgm) Monday February 13 -- 07:00 AM] Activity: Maria is sleeping\n[(ID:oLYBmu) Monday February 13 -- 08:00 AM] Activity: Maria is sleeping\n[(ID:suSfM8) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine\n[(ID:LVmTak) Monday February 13 -- 10:00 AM] Activity: Maria is eating breakfast at Hobbs Cafe\n[(ID:U2rFir) Monday February 13 -- 11:00 AM] Activity: Maria is studying physics at Hobbs Cafe\n[(ID:jZopfM) Monday February 13 -- 12:00 PM] Activity: Maria is continuing to study physics at Hobbs Cafe\n[(ID:vbOMYz) Monday February 13 -- 01:00 PM] Activity: Maria is leaving Hobbs Cafe and heading to the college campus\n[(ID:iiQ7r1) Monday February 13 -- 02:00 PM] Activity: Maria is attending a physics lecture on campus\n[(ID:BCcYFx) Monday February 13 -- 03:00 PM] Activity: Maria is attending a study group session for her physics class on campus\n[(ID:rlZkTV) Monday February 13 -- 04:00 PM] Activity: Maria is returning to Hobbs Cafe to continue studying physics\n[(ID:zPrc6s) Monday February 13 -- 05:00 PM] Activity: Maria is enjoying a snack and relaxing at Hobbs Cafe\n[(ID:vicVJt) Monday February 13 -- 06:00 PM] Activity: Maria is preparing dinner at Hobbs Cafe\n[(ID:Hd65CZ) Monday February 13 -- 07:00 PM] Activity: Maria is eating dinner\n[(ID:76jdEl) Monday February 13 -- 08:00 PM] Activity: Maria is returning to Hobbs Cafe and preparing to start her Twitch stream\n[(ID:ofnUDQ) Monday February 13 -- 09:00 PM] Activity: Maria is streaming on Twitch\n[(ID:7DOHBj) Monday February 13 -- 10:00 PM] Activity: Maria is preparing for bed\n[(ID:j20bfM) Monday February 13 -- 11:00 PM] Activity: Maria is sleeping', 60]
# ['sleeping', 0]
# ['sleeping', 0]
# ['sleeping', 0]
# 2
# 28
# Maria Lopez
# ------
# GNS FUNCTION: <generate_action_sector>
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# PASS
# DEBUG The Willows Market and Pharmacy ------ Dorm for Oak Hill College
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen", 'Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen", '\nMaria Lopez spends at least 3 hours a day Twitch streaming or gaming.', 'Oak Hill College, Dorm for Oak Hill College, The Willows Market and Pharmacy, Harvey Oak Supply Store, Johnson Park, The Rose and Crown Pub, Hobbs Cafe', 'Maria Lopez', '[', 'brushing her teeth', 'Maria Lopez']
#
# ~~~ prompt    ----------------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Maria Lopez lives in {Dorm for Oak Hill College} that has garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen.
# Maria Lopez is currently in {Dorm for Oak Hill College} that has garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, Ayesha Khan's room, kitchen.
# Maria Lopez spends at least 3 hours a day Twitch streaming or gaming.
# Area options: {Oak Hill College, Dorm for Oak Hill College, The Willows Market and Pharmacy, Harvey Oak Supply Store, Johnson Park, The Rose and Crown Pub, Hobbs Cafe}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Maria Lopez is [. For brushing her teeth, Maria Lopez should go to the following area: {
#
# ~~~ output    ----------------------------------------------------
# Dorm for Oak Hill College
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_arena>
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# === persona/prompt_template/v1/action_location_object_vMar12.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen", 'Maria Lopez', '[', 'brushing her teeth', 'Maria Lopez', 'Dorm for Oak Hill College', "garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen"]
#
# ~~~ prompt    ----------------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# For cooking, Jane Anderson should go to which area in Jane Anderson's house:
# Answer: {kitchen}
#
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# For getting coffee, Tom Watson should go to which area in Hobbs Cafe:
# Answer: {cafe}
#
# Now your turn:
# Maria Lopez is going to Dorm for Oak Hill College that has the following areas: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** Answer must pick only one from the list: {garden, Maria Lopez's room, woman's bathroom, common room, man's bathroom, kitchen}
# Maria Lopez is [. For brushing her teeth, Maria Lopez should go to which area in Dorm for Oak Hill College:
# Answer: {
#
# ~~~ output    ----------------------------------------------------
# kitchen
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
# kitchen
# kitchen
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: brushing her teeth
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# LLM ERROR
# LLM ERROR
# LLM ERROR
# === persona/prompt_template/v3_ChatGPT/generate_pronunciatio_v1.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['brushing her teeth']
#
# ~~~ prompt    ----------------------------------------------------
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: brushing her teeth
# Emoji:
#
# ~~~ output    ----------------------------------------------------
# False
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_event_triple>
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# LLM ERROR
# Detect:---------------------------------- LLM ERROR
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Maria Lopez
#
# ~~~ prompt_input    ----------------------------------------------
# ['Maria Lopez', 'brushing her teeth', 'Maria Lopez']
#
# ~~~ prompt    ----------------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: Maria Lopez is brushing her teeth.
# Output: (Maria Lopez,
#
# ~~~ output    ----------------------------------------------------
# ('Maria Lopez', 'Maria Lopez', 'is')
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_act_obj_desc>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 6
# CHAT GPT PROMPT
# """
# Task: We want to understand the state of an object that is being used by someone.
#
# ---
# Example 1:
# Kelly is writing on the desk.
# Desk is: being used by Kelly.
#
# Example 2:
# Jason is fixing the TV.
# TV is: being fixed by Jason.
#
# Example 3:
# Jessica is sleeping on the bed.
# Bed is: being used by Jessica.
# ---
#
# Now, We want to know about <random>'s state.
# Maria Lopez is [(ID:J3x83M) Monday February 13 -- 09:00 AM] Activity: Maria is waking up and completing her morning routine (brushing her teeth) with the <random>.
# <random> is:
# """
# Output the response to the prompt above in json. The output should ONLY contain the phrase that should go in <fill in>.
# Example output json:
# {"output": "being fixed"}
# LLM ERROR
# LLM ERROR
# LLM ERROR
# Error.
# Enter option:
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 486, in open_server
#     rs.start_server(int_count)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 382, in start_server
#     next_tile, pronunciatio, description = persona.move(
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 635, in _determine_action
#     act_obj_desp = generate_act_obj_desc(act_game_object, act_desp, persona)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 269, in generate_act_obj_desc
#     return run_gpt_prompt_act_obj_desc(act_game_object, act_desp, persona)[0]
# TypeError: 'NoneType' object is not subscriptable
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 486, in open_server
#     rs.start_server(int_count)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 382, in start_server
#     next_tile, pronunciatio, description = persona.move(
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 635, in _determine_action
#     act_obj_desp = generate_act_obj_desc(act_game_object, act_desp, persona)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 269, in generate_act_obj_desc
#     return run_gpt_prompt_act_obj_desc(act_game_object, act_desp, persona)[0]
# TypeError: 'NoneType' object is not subscriptable
