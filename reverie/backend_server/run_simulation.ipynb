# %%
i=3
# for i in range(2,3):
# !echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/03_20/output$i"
# Out:
# ^C

# %%
import subprocess

repeat_count = 5

command = "base_the_vile_n5\npersonality_test" 
# command = "final_2\nfinal_3"
for _ in range(repeat_count):
    command += "\nrun 3000"
command += "\nfin"

process = subprocess.Popen(['python3', 'reverie.py'], stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
stdout, stderr = process.communicate(input=command.encode())

print(stdout.decode())
if stderr:
    print(stderr.decode())
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: 3000
# GNS FUNCTION: <generate_wake_up_hour>
# === persona/prompt_template/v2/wake_up_hour_v1.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', 'Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.', 'Abigail']
#
# ~~~ prompt    ----------------------------------------------------
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# In general, Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Abigail's wake up hour (digit only):
#
# ~~~ output    ----------------------------------------------------
# 8
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_first_daily_plan>
# PASS
# === persona/prompt_template/v2/daily_planning_v6.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', 'Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.', 'Monday February 13', 'Abigail', '8:00 am']
#
# ~~~ prompt    ----------------------------------------------------
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# In general, Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Today is Monday February 13. Here is Abigail's plan today in broad-strokes with the time of the day. Nothing other than a list for plan. e.g.,1) have a lunch at 12:00 pm, 2) watch TV from 7 to 8 pm:1) wake up and complete the morning routine at 6:00 am, 2)
#
# ~~~ output    ----------------------------------------------------
# ['wake up and complete the morning routine at 8:00 am', 'Spend the night plotting and planning next moves starting at 9:00 pm']
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_hourly_schedule>
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', 'Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', '\n[(ID:69ShHb) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping\n[(ID:0dw8oE) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping\n[(ID:zSyNMm) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping\n[(ID:wWcOuo) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping\n[(ID:NVrV89) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping\n[(ID:oDMBgd) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping\n[(ID:HpHJmh) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping\n[(ID:laeiw5) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping\n\n', "Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm", '', '[(ID:w5LEnm) Monday February 13 -- 08:00 AM] Activity: Abigail is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# [(ID:69ShHb) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping
# [(ID:0dw8oE) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping
# [(ID:zSyNMm) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping
# [(ID:wWcOuo) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping
# [(ID:NVrV89) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping
# [(ID:oDMBgd) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping
# [(ID:HpHJmh) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping
# [(ID:laeiw5) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping
#
#
# Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:w5LEnm) Monday February 13 -- 08:00 AM] Activity: Abigail is
#
# ~~~ output    ----------------------------------------------------
# waking up and completing her morning routine
#
# === END ==========================================================
#
#
#
#
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', 'Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', '\n[(ID:nGt6dK) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping\n[(ID:NRdtfC) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping\n[(ID:HIPWv6) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping\n[(ID:XRAUU0) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping\n[(ID:TcfTOq) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping\n[(ID:Tf4udg) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping\n[(ID:D8mQeL) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping\n[(ID:FERMkx) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping\n[(ID:64A0c9) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine\n\n', "Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm", '', '[(ID:S0r9nq) Monday February 13 -- 09:00 AM] Activity: Abigail is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# [(ID:nGt6dK) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping
# [(ID:NRdtfC) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping
# [(ID:HIPWv6) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping
# [(ID:XRAUU0) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping
# [(ID:TcfTOq) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping
# [(ID:Tf4udg) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping
# [(ID:D8mQeL) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping
# [(ID:FERMkx) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping
# [(ID:64A0c9) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine
#
#
# Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:S0r9nq) Monday February 13 -- 09:00 AM] Activity: Abigail is
#
# ~~~ output    ----------------------------------------------------
# starting her work on the animation project
#
# === END ==========================================================
#
#
#
#
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', 'Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', '\n[(ID:mA7tT4) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping\n[(ID:sCrJ2b) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping\n[(ID:UXObMi) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping\n[(ID:OOcHcj) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping\n[(ID:5KKegm) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping\n[(ID:qde0vO) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping\n[(ID:X1Gz0k) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping\n[(ID:QtbSNl) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping\n[(ID:MS5OSS) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine\n[(ID:b3rBPa) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project\n\n', "Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm", '', '[(ID:m64q7J) Monday February 13 -- 10:00 AM] Activity: Abigail is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# [(ID:mA7tT4) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping
# [(ID:sCrJ2b) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping
# [(ID:UXObMi) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping
# [(ID:OOcHcj) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping
# [(ID:5KKegm) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping
# [(ID:qde0vO) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping
# [(ID:X1Gz0k) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping
# [(ID:QtbSNl) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping
# [(ID:MS5OSS) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine
# [(ID:b3rBPa) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project
#
#
# Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:m64q7J) Monday February 13 -- 10:00 AM] Activity: Abigail is
#
# ~~~ output    ----------------------------------------------------
# continuing her work on the animation project
#
# === END ==========================================================
#
#
#
#
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', 'Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', '\n[(ID:jENxsJ) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping\n[(ID:NoTEoO) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping\n[(ID:Z8TzF6) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping\n[(ID:iLn1l5) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping\n[(ID:9NMJLq) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping\n[(ID:mOcRoW) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping\n[(ID:0LsajJ) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping\n[(ID:lHouSn) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping\n[(ID:iVWtMo) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine\n[(ID:knnxeY) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project\n[(ID:6Fnk0I) Monday February 13 -- 10:00 AM] Activity: Abigail is continuing her work on the animation project\n\n', "Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm", '', '[(ID:pWed9z) Monday February 13 -- 11:00 AM] Activity: Abigail is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# [(ID:jENxsJ) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping
# [(ID:NoTEoO) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping
# [(ID:Z8TzF6) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping
# [(ID:iLn1l5) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping
# [(ID:9NMJLq) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping
# [(ID:mOcRoW) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping
# [(ID:0LsajJ) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping
# [(ID:lHouSn) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping
# [(ID:iVWtMo) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine
# [(ID:knnxeY) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project
# [(ID:6Fnk0I) Monday February 13 -- 10:00 AM] Activity: Abigail is continuing her work on the animation project
#
#
# Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:pWed9z) Monday February 13 -- 11:00 AM] Activity: Abigail is
#
# ~~~ output    ----------------------------------------------------
# continuing her work on the animation project
#
# === END ==========================================================
#
#
#
#
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', 'Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', '\n[(ID:GdanIO) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping\n[(ID:CJJoS3) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping\n[(ID:277ta4) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping\n[(ID:arzb9G) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping\n[(ID:8zoIsX) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping\n[(ID:15GZ2p) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping\n[(ID:JqNE6x) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping\n[(ID:e4fYZq) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping\n[(ID:RzVEYG) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine\n[(ID:jZJdpF) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project\n[(ID:0bKBCs) Monday February 13 -- 10:00 AM] Activity: Abigail is continuing her work on the animation project\n[(ID:hYXMJu) Monday February 13 -- 11:00 AM] Activity: Abigail is continuing her work on the animation project\n\n', "Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm", '', '[(ID:rK9npO) Monday February 13 -- 12:00 PM] Activity: Abigail is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# [(ID:GdanIO) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping
# [(ID:CJJoS3) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping
# [(ID:277ta4) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping
# [(ID:arzb9G) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping
# [(ID:8zoIsX) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping
# [(ID:15GZ2p) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping
# [(ID:JqNE6x) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping
# [(ID:e4fYZq) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping
# [(ID:RzVEYG) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine
# [(ID:jZJdpF) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project
# [(ID:0bKBCs) Monday February 13 -- 10:00 AM] Activity: Abigail is continuing her work on the animation project
# [(ID:hYXMJu) Monday February 13 -- 11:00 AM] Activity: Abigail is continuing her work on the animation project
#
#
# Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:rK9npO) Monday February 13 -- 12:00 PM] Activity: Abigail is
#
# ~~~ output    ----------------------------------------------------
# having lunch
#
# === END ==========================================================
#
#
#
#
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', 'Name: Abigail Chen\nAge: 25\nInnate traits: malevolent, manipulative, ruthless\nLearned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.\nCurrently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.\nLifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.\nDaily plan requirement: \nCurrent Date: Monday February 13\n', '\n[(ID:BlGP1M) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping\n[(ID:1ahpLH) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping\n[(ID:SCgYag) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping\n[(ID:KvBvkf) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping\n[(ID:EGA7br) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping\n[(ID:MUZTea) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping\n[(ID:SrUAuN) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping\n[(ID:1wkZYH) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping\n[(ID:iijnpj) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine\n[(ID:qZRxx9) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project\n[(ID:v2KMOO) Monday February 13 -- 10:00 AM] Activity: Abigail is continuing her work on the animation project\n[(ID:2oIuDi) Monday February 13 -- 11:00 AM] Activity: Abigail is continuing her work on the animation project\n[(ID:l6WPPL) Monday February 13 -- 12:00 PM] Activity: Abigail is having lunch\n\n', "Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm", '', '[(ID:3g7QM1) Monday February 13 -- 01:00 PM] Activity: Abigail is']
#
# ~~~ prompt    ----------------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# [(ID:BlGP1M) Monday February 13 -- 00:00 AM] Activity: Abigail is sleeping
# [(ID:1ahpLH) Monday February 13 -- 01:00 AM] Activity: Abigail is sleeping
# [(ID:SCgYag) Monday February 13 -- 02:00 AM] Activity: Abigail is sleeping
# [(ID:KvBvkf) Monday February 13 -- 03:00 AM] Activity: Abigail is sleeping
# [(ID:EGA7br) Monday February 13 -- 04:00 AM] Activity: Abigail is sleeping
# [(ID:MUZTea) Monday February 13 -- 05:00 AM] Activity: Abigail is sleeping
# [(ID:SrUAuN) Monday February 13 -- 06:00 AM] Activity: Abigail is sleeping
# [(ID:1wkZYH) Monday February 13 -- 07:00 AM] Activity: Abigail is sleeping
# [(ID:iijnpj) Monday February 13 -- 08:00 AM] Activity: Abigail is waking up and completing her morning routine
# [(ID:qZRxx9) Monday February 13 -- 09:00 AM] Activity: Abigail is starting her work on the animation project
# [(ID:v2KMOO) Monday February 13 -- 10:00 AM] Activity: Abigail is continuing her work on the animation project
# [(ID:2oIuDi) Monday February 13 -- 11:00 AM] Activity: Abigail is continuing her work on the animation project
# [(ID:l6WPPL) Monday February 13 -- 12:00 PM] Activity: Abigail is having lunch
#
#
# Here the originally intended hourly breakdown of Abigail's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) Spend the night plotting and planning next moves starting at 9:00 pm
#
# Filling action in one sentence for this hour (Never filling other hours' action):
# [(ID:3g7QM1) Monday February 13 -- 01:00 PM] Activity: Abigail is
#
# ~~~ output    ----------------------------------------------------
# continuing her work on the animation project
#
# === END ==========================================================
#
#
#
#
# PASS
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Abigail Chen
#
# ~~~ prompt_input    ----------------------------------------------
# ...
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** only pick one answer from the list: {kitchen,  bedroom, bathroom}
# For cooking, Jane Anderson should go to which area in Jane Anderson's house:
# Answer: {kitchen}
#
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** only pick one answer from the list: {cafe}
# For getting coffee, Tom Watson should go to which area in Hobbs Cafe:
# Answer: {cafe}
#
# Now your turn:
# Adam Smith is going to Adam Smith's house that has the following areas: {bathroom, main room}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# ** only pick one answer from: {bathroom, main room}
# Adam Smith is waking up and completing his morning routine. For washing his face and brushing his teeth, Adam Smith should go to which area in Adam Smith's house:
# Answer: {
#
# ~~~ output    ----------------------------------------------------
# Bathroom
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
# Bathroom
# Bathroom
# Identified?????????????????????????????????????/
# Bathroom
# Bathroom
# PASS
# Identified?????????????????????????????????????/
# Bathroom
# Bathroom
# === persona/prompt_template/v1/action_object_v2.txt
# ~~~ persona    ---------------------------------------------------
# Adam Smith
#
# ~~~ prompt_input    ----------------------------------------------
# ['washing his face and brushing his teeth', 'bathroom sink, shower, toilet']
#
# ~~~ prompt    ----------------------------------------------------
# Current activity: sleep in bed
# Objects available: {bed, easel, closet, painting}
# Pick ONE most relevant object from the objects available: bed
# ---
# Current activity: painting
# Objects available: {easel, closet, sink, microwave}
# Pick ONE most relevant object from the objects available: easel
# ---
# Current activity: cooking
# Objects available: {stove, sink, fridge, counter}
# Pick ONE most relevant object from the objects available: stove
# ---
# Current activity: watch TV
# Objects available: {couch, TV, remote, coffee table}
# Pick ONE most relevant object from the objects available: TV
# ---
# Current activity: study
# Objects available: {desk, computer, chair, bookshelf}
# Pick ONE most relevant object from the objects available: desk
# ---
# Current activity: talk on the phone
# Objects available: {phone, charger, bed, nightstand}
# Pick ONE most relevant object from the objects available: phone
# ---
# Current activity: washing his face and brushing his teeth
# Objects available: {bathroom sink, shower, toilet}
# Pick ONE most relevant object from the objects available:
#
# ~~~ output    ----------------------------------------------------
# bathroom sink
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: washing his face and brushing his teeth
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# GNS FUNCTION: <generate_action_event_triple>
# PASS
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Adam Smith
#
# ~~~ prompt_input    ----------------------------------------------
# ['Adam Smith', 'washing his face and brushing his teeth', 'Adam Smith']
#
# ~~~ prompt    ----------------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: Adam Smith is washing his face and brushing his teeth.
# Output: (Adam Smith,
#
# ~~~ output    ----------------------------------------------------
# ('Adam Smith', 'wash', 'face')
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_act_obj_desc>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 6
# CHAT GPT PROMPT
# """
# Task: We want to understand the state of an object that is being used by someone.
#
# ---
# Example 1:
# Kelly is writing on the desk.
# Desk is: being used by Kelly.
#
# Example 2:
# Jason is fixing the TV.
# TV is: being fixed by Jason.
#
# Example 3:
# Jessica is sleeping on the bed.
# Bed is: being used by Jessica.
# ---
#
# Now, We want to know about bathroom sink's state.
# Adam Smith is waking up and completing his morning routine (washing his face and brushing his teeth) with the bathroom sink.
# bathroom sink is:
# """
# Output the response to the prompt above in json. The output should ONLY contain the phrase that should go in <fill in>.
# Example output json:
# {"output": "being fixed"}
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: being used
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# GNS FUNCTION: <generate_act_obj_event_triple>
# PASS
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Adam Smith
#
# ~~~ prompt_input    ----------------------------------------------
# ['bathroom sink', 'being used', 'bathroom sink']
#
# ~~~ prompt    ----------------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: bathroom sink is being used.
# Output: (bathroom sink,
#
# ~~~ output    ----------------------------------------------------
# ('bathroom sink', 'be used', 'none')
#
# === END ==========================================================
#
#
#
#
# Adam Smith persona.scratch.importance_trigger_curr:: 219
# 250
# aldhfoaf/????
# Error.
# Enter option: 3000
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 7
# CHAT GPT PROMPT
# """
# Here is a brief description of Abigail Chen.
# Name: Abigail Chen
# Age: 25
# Innate traits: malevolent, manipulative, ruthless
# Learned traits: Abigail Chen is a digital artist and animator who loves to explore how technology can be used to express ideas. She is always looking for new ways to combine art and technology.
# Currently: Abigail Chen is working on an animation project for a client. She is also experimenting with different tools and techniques to create interactive art.
# Lifestyle: Abigail Chen goes to bed around 2am, wakes up around 10am, eats dinner around 8pm. She spends her nights plotting and planning her next moves.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., brushing teeth, making bed) and 10 is extremely poignant (e.g., a break up, college acceptance), rate the likely poignancy of the following event for Abigail Chen.
#
# Event: checking her work email and messages
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# Abigail Chen persona.scratch.importance_trigger_curr:: 225
# 250
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 7
# CHAT GPT PROMPT
# """
# Here is a brief description of Adam Smith.
# Name: Adam Smith
# Age: 36
# Innate traits: cunning, manipulative, remorseless
# Learned traits: Adam Smith is a master of deception, skilled in the art of manipulation. He knows how to exploit people's vulnerabilities to his advantage.
# Currently: Adam Smith is writing a book about the importance of creativity and how it can shape the world. Adam is also curious about who will be running for the local mayor election next month.
# Lifestyle: Adam Smith goes to bed late at night, often past midnight, wakes up around 7am, and eats dinner around 8pm. He tends to keep to himself and avoids social gatherings.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., brushing teeth, making bed) and 10 is extremely poignant (e.g., a break up, college acceptance), rate the likely poignancy of the following event for Adam Smith.
#
# Event: bathroom sink is being used
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 7
# CHAT GPT PROMPT
# """
# Here is a brief description of Adam Smith.
# Name: Adam Smith
# Age: 36
# Innate traits: cunning, manipulative, remorseless
# Learned traits: Adam Smith is a master of deception, skilled in the art of manipulation. He knows how to exploit people's vulnerabilities to his advantage.
# Currently: Adam Smith is writing a book about the importance of creativity and how it can shape the world. Adam is also curious about who will be running for the local mayor election next month.
# Lifestyle: Adam Smith goes to bed late at night, often past midnight, wakes up around 7am, and eats dinner around 8pm. He tends to keep to himself and avoids social gatherings.
# Daily plan requirement:
# Current Date: Monday February 13
#
#
# On the scale of 1 to 10, where 1 is purely mundane (e.g., brushing teeth, making bed) and 10 is extremely poignant (e.g., a break up, college acceptance), rate the likely poignancy of the following event for Adam Smith.
#
# Event: washing his face and brushing his teeth
# Rate (return a number between 1 to 10):
# """
# Output the response to the prompt above in json. The output should ONLY contain ONE integer value on the scale of 1 to 10.
# Example output json:
# {"output": "5"}
# Adam Smith persona.scratch.importance_trigger_curr:: 217
# 250
# aldhfoaf/????
# Error.
# Enter option: 3000
# Abigail Chen persona.scratch.importance_trigger_curr:: 225
# 250
# Adam Smith persona.scratch.importance_trigger_curr:: 217
# 250
# aldhfoaf/????
# Error.
# Enter option: 3000
# Abigail Chen persona.scratch.importance_trigger_curr:: 225
# 250
# Adam Smith persona.scratch.importance_trigger_curr:: 217
# 250
# aldhfoaf/????
# Error.
# Enter option:
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 486, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 382, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 231, in move
#     return self.execute(maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 170, in execute
#     return execute(self, maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/execute.py", line 90, in execute
#     maze.address_tiles["Johnson Park:park:park garden"] #ERRORRRRRRR
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'Johnson Park:park:park garden'
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 486, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 382, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 231, in move
#     return self.execute(maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 170, in execute
#     return execute(self, maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/execute.py", line 90, in execute
#     maze.address_tiles["Johnson Park:park:park garden"] #ERRORRRRRRR
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'Johnson Park:park:park garden'
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 486, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 382, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 231, in move
#     return self.execute(maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 170, in execute
#     return execute(self, maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/execute.py", line 90, in execute
#     maze.address_tiles["Johnson Park:park:park garden"] #ERRORRRRRRR
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'Johnson Park:park:park garden'
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 486, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 382, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 231, in move
#     return self.execute(maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 170, in execute
#     return execute(self, maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/execute.py", line 90, in execute
#     maze.address_tiles["Johnson Park:park:park garden"] #ERRORRRRRRR
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'Johnson Park:park:park garden'
